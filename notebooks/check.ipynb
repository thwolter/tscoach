# %%
from langgraph_sdk import get_client
client = get_client(url="http://localhost:8123", headers={'Authorization': 'Bearer '})

# %%
await client.threads.create()
# Out:
# [{'thread_id': '6ed6eae1-9e68-4ee2-be76-ff586de7ba56',
#   'created_at': '2026-04-14T10:34:01.861045+00:00',
#   'updated_at': '2026-04-14T10:37:56.711311+00:00',
#   'state_updated_at': '2026-04-14T10:37:56.711311+00:00',
#   'metadata': {'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#    'graph_id': 'agent'},
#   'config': {'configurable': {'__after_seconds__': 0,
#     '__request_start_time_ms__': 1776163071543,
#     'assistant_id': 'fe096781-5601-53d2-b2f6-0d3403f7e9ca',
#     'langgraph_auth_permissions': [],
#     'langgraph_auth_user': None,
#     'langgraph_auth_user_id': '',
#     'langgraph_request_id': '1c253a1c-8c76-46a7-b1fc-271645ff6365',
#     'run_id': '019d8b91-a637-7443-8f2d-aadcc5f176c8',
#     'user_id': ''}},
#   'error': None,
#   'status': 'idle',
#   'values': {'audit_log': [],
#    'caller_profile': {'complexity': 5,
#     'cooperativeness': 0.08,
#     'emotional_state': 'moderate distress',
#     'volatility': 0.72},
# ...
